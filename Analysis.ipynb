# %%
# Load and Explore the Dataset
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris

# %%
# Load dataset from sklearn
iris = load_iris(as_frame=True)
df = iris.frame  # DataFrame version

# Add target (species names) to the DataFrame
df['species'] = df['target'].apply(lambda x: iris.target_names[x])

# Display first few rows
print("First 5 rows of dataset:")
df.head()
# Out:
# First 5 rows of dataset:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target species
# 0       0  setosa
# 1       0  setosa
# 2       0  setosa
# 3       0  setosa
# 4       0  setosa

# %%
# Check structure of dataset
print("\nDataset Info:")
print(df.info())

print("\nMissing values per column:")
print(df.isnull().sum())

# No missing values here, but we’ll show how to handle if they exist:
# df = df.dropna()   # OR df.fillna(method='ffill')
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   target             150 non-null    int64
#  5   species            150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB
# None
#
# Missing values per column:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# target               0
# species              0
# dtype: int64

# %%
 #Basic Data Analysis
print("\nBasic Statistics:")
display(df.describe())

# Group by species and compute mean of numerical columns
species_means = df.groupby("species").mean()
print("\nAverage values per species:")
display(species_means)
# Out:
# Basic Statistics:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)      target
# count        150.000000  150.000000
# mean           1.199333    1.000000
# std            0.762238    0.819232
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000
# Average values per species:
# ...

# %%
# Task 3: Data Visualization

# Line chart: Trend of sepal length values (just as an example, sorted)
plt.figure(figsize=(8,5))
plt.plot(sorted(df["sepal length (cm)"].values))
plt.title("Line Chart: Sorted Sepal Length Values")
plt.xlabel("Index")
plt.ylabel("Sepal Length (cm)")
plt.show()

# Bar chart: Average petal length per species
plt.figure(figsize=(8,5))
sns.barplot(x=species_means.index, y=species_means["petal length (cm)"], palette="viridis")
plt.title("Average Petal Length by Species")
plt.xlabel("Species")
plt.ylabel("Petal Length (cm)")
plt.show()

# Histogram: Distribution of sepal length
plt.figure(figsize=(8,5))
plt.hist(df["sepal length (cm)"], bins=15, color="skyblue", edgecolor="black")
plt.title("Histogram of Sepal Length")
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Frequency")
plt.show()

# Scatter plot: Sepal length vs. Petal length
plt.figure(figsize=(8,5))
sns.scatterplot(x="sepal length (cm)", y="petal length (cm)", hue="species", data=df, palette="Set1")
plt.title("Scatter Plot: Sepal Length vs Petal Length")
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Petal Length (cm)")
plt.legend(title="Species")
plt.show()

# Error Handling Example: Reading a CSV (uncomment for custom dataset)
"""
try:
    df_custom = pd.read_csv("your_dataset.csv")
    print("Dataset loaded successfully!")
except FileNotFoundError:
    print("Error: The file was not found. Please check the path.")
except pd.errors.ParserError:
    print("Error: Problem parsing the file. Please check the format.")
"""

# ------------------------------------------
# Findings:
# - Setosa species generally have smaller petal dimensions.
# - Virginica species tends to have the largest flower parts.
# - Sepal length distribution shows most flowers between 5 and 7 cm.
# - Strong positive relationship between sepal length and petal length.
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9928\2617565613.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=species_means.index, y=species_means["petal length (cm)"], palette="viridis")
# '\ntry:\n    df_custom = pd.read_csv("your_dataset.csv")\n    print("Dataset loaded successfully!")\nexcept FileNotFoundError:\n    print("Error: The file was not found. Please check the path.")\nexcept pd.errors.ParserError:\n    print("Error: Problem parsing the file. Please check the format.")\n'
